# %%
# importing Essential Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import datasets

df = pd.read_csv('Market_Basket_Optimisation.csv',header=None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
df.shape
# Out:
# (7501, 20)

# %%
transactions = []
for items in range(0,7501):
    transactions.append([str(df.values[items,j]) for j in range(0,20)])

# %%
# Training the Apriori Model on the datasets
# ! pip install apyori
from apyori import apriori
rules = apriori(transactions=transactions,min_support = .003,min_confidence = 0.2, min_lift = 2, min_length = 2,max_length=2 )

# %%
# Display the first results coming directly from the output of apriori
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'almonds', 'burgers'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'bacon', 'spaghetti'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.36923076923076925, lift=2.1206738131699847)]),
#  RelationRecord(items=frozenset({'milk', 'black tea'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'milk'}), confidence=0.29906542056074764, lift=2.3079112341833006)]),
# ...

# %%
# Putting the data in Pandas Dataframe
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs,rhs,supports,confidences,lifts))
df1 = pd.DataFrame(inspect(results),columns=['Left Hand Side','Right Hand Side','Support','Confidence','Lift'])

# %%
# displaying the result
df1

# Shorthing the Dataset in decsending order

df1.nlargest(n = 10, columns = 'Lift')
# Out:
#           Left Hand Side Right Hand Side   Support  Confidence      Lift
# 16         fromage blanc           honey  0.003333    0.245098  5.164271
# 7            light cream         chicken  0.004533    0.290598  4.843951
# 12                 pasta        escalope  0.005866    0.372881  4.700812
# 38                 pasta          shrimp  0.005066    0.322034  4.506672
# 37     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 29          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 11  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 22         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 30           light cream       olive oil  0.003200    0.205128  3.114710
# 0                almonds         burgers  0.005199    0.254902  2.923577
